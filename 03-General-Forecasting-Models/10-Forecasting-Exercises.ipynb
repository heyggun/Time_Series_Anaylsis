# %% [markdown]
# ___
#
# <a href='http://www.pieriandata.com'><img src='../Pierian_Data_Logo.png'/></a>
# ___
# <center><em>Copyright Pierian Data</em></center>
# <center><em>For more information, visit us at <a href='http://www.pieriandata.com'>www.pieriandata.com</a></em></center>

# %% [markdown]
# # Forecasting Exercises
#
# - 계절성 ARIMA 예측 연습 문제
# This exercise walks through a SARIMA prediction and forecast similar to the one done on the Mauna Loa CO₂ dataset.<br>
# This time we're using a seasonal time series of California Hospitality Industry Employees.
#
# <div class="alert alert-danger" style="margin: 10px"><strong>IMPORTANT NOTE!</strong> Make sure you don't run the cells directly above the example output shown, <br>otherwise you will end up writing over the example output!</div>

# %%
# RUN THIS CELL
import pandas as pd
import numpy as np
# %matplotlib inline

# Load specific forecasting tools
from statsmodels.tsa.statespace.sarimax import SARIMAX

from statsmodels.graphics.tsaplots import plot_acf,plot_pacf # for determining (p,q) orders
from statsmodels.tsa.seasonal import seasonal_decompose      # for ETS Plots
from pmdarima import auto_arima                              # for determining ARIMA orders

# Load specific evaluation tools
from sklearn.metrics import mean_squared_error
from statsmodels.tools.eval_measures import rmse

# Ignore harmless warnings
import warnings
warnings.filterwarnings("ignore")

# Load datasets
df = pd.read_csv('data/HospitalityEmployees.csv',index_col='Date',parse_dates=True)
df.index.freq = 'MS'
print(len(df))
print(df.head())
# Out:
# 348
#             Employees
# Date
# 1990-01-01     1064.5
# 1990-02-01     1074.5
# 1990-03-01     1090.0
# 1990-04-01     1097.4
# 1990-05-01     1108.7

# %% [markdown]
# So <tt>df</tt> has 348 records and one column. The data represents the number of employees in thousands of persons as monthly averages from January, 1990 to December 2018.
#
# - 캘리포니아 서비스업 직원에 대한 계절성 시계열 데이터 사용

# %% [markdown]
# ### 1. Plot the source data
# Create a line chart of the dataset. Optional: add a title and y-axis label.
#
# - `원본 데이터를 플롯으로 그리기`

# %%
## CODE HERE

df['Employees'].plot(figsize=(12,5));

# %%
# DON'T WRITE HERE

# %% [markdown]
# ### 2. Run an ETS Decomposition
# Use an 'additive' model.
#
# `ETS 분해 실행`

# %%
result = seasonal_decompose(df['Employees'], model='add')
result.plot();

# %%
# DON'T WRITE HERE

# %% [markdown]
# ### 3. Run <tt>pmdarima.auto_arima</tt> to obtain recommended orders
# This may take awhile as there are a lot of combinations to evaluate.
#
# - `자동 ARIMA 실행하여 추천 받은 차수 구함`

# %%
auto_arima(df['Employees'], seasonal=True, m=12, trace=True).summary()
# Out:
# Performing stepwise search to minimize aic
#  ARIMA(2,1,2)(1,0,1)[12] intercept   : AIC=2213.076, Time=0.84 sec
#  ARIMA(0,1,0)(0,0,0)[12] intercept   : AIC=2974.636, Time=0.01 sec
#  ARIMA(1,1,0)(1,0,0)[12] intercept   : AIC=inf, Time=0.20 sec
#  ARIMA(0,1,1)(0,0,1)[12] intercept   : AIC=2707.381, Time=0.20 sec
#  ARIMA(0,1,0)(0,0,0)[12]             : AIC=2980.790, Time=0.01 sec
#  ARIMA(2,1,2)(0,0,1)[12] intercept   : AIC=inf, Time=0.65 sec
#  ARIMA(2,1,2)(1,0,0)[12] intercept   : AIC=2340.936, Time=0.46 sec
#  ARIMA(2,1,2)(2,0,1)[12] intercept   : AIC=2218.469, Time=2.14 sec
#  ARIMA(2,1,2)(1,0,2)[12] intercept   : AIC=2315.425, Time=2.57 sec
#  ARIMA(2,1,2)(0,0,0)[12] intercept   : AIC=inf, Time=0.27 sec
#  ARIMA(2,1,2)(0,0,2)[12] intercept   : AIC=inf, Time=1.50 sec
#  ARIMA(2,1,2)(2,0,0)[12] intercept   : AIC=2264.870, Time=1.41 sec
#  ARIMA(2,1,2)(2,0,2)[12] intercept   : AIC=inf, Time=2.19 sec
#  ARIMA(1,1,2)(1,0,1)[12] intercept   : AIC=2210.604, Time=0.86 sec
#  ARIMA(1,1,2)(0,0,1)[12] intercept   : AIC=2703.032, Time=0.32 sec
#  ARIMA(1,1,2)(1,0,0)[12] intercept   : AIC=2344.522, Time=0.32 sec
#  ARIMA(1,1,2)(2,0,1)[12] intercept   : AIC=2214.087, Time=1.95 sec
#  ARIMA(1,1,2)(1,0,2)[12] intercept   : AIC=2514.121, Time=0.72 sec
#  ARIMA(1,1,2)(0,0,0)[12] intercept   : AIC=2961.373, Time=0.19 sec
#  ARIMA(1,1,2)(0,0,2)[12] intercept   : AIC=2596.838, Time=0.93 sec
#  ARIMA(1,1,2)(2,0,0)[12] intercept   : AIC=2282.409, Time=1.14 sec
#  ARIMA(1,1,2)(2,0,2)[12] intercept   : AIC=inf, Time=1.55 sec
#  ARIMA(0,1,2)(1,0,1)[12] intercept   : AIC=2229.077, Time=0.48 sec
#  ARIMA(1,1,1)(1,0,1)[12] intercept   : AIC=2236.826, Time=0.45 sec
#  ARIMA(1,1,3)(1,0,1)[12] intercept   : AIC=2232.764, Time=0.85 sec
#  ARIMA(0,1,1)(1,0,1)[12] intercept   : AIC=2233.847, Time=0.42 sec
#  ARIMA(0,1,3)(1,0,1)[12] intercept   : AIC=2228.010, Time=0.58 sec
#  ARIMA(2,1,1)(1,0,1)[12] intercept   : AIC=inf, Time=nan sec
#  ARIMA(2,1,3)(1,0,1)[12] intercept   : AIC=2241.533, Time=1.07 sec
#  ARIMA(1,1,2)(1,0,1)[12]             : AIC=2208.504, Time=0.49 sec
#  ARIMA(1,1,2)(0,0,1)[12]             : AIC=2704.499, Time=0.21 sec
#  ARIMA(1,1,2)(1,0,0)[12]             : AIC=2337.722, Time=0.26 sec
#  ARIMA(1,1,2)(2,0,1)[12]             : AIC=2210.068, Time=1.50 sec
#  ARIMA(1,1,2)(1,0,2)[12]             : AIC=2210.040, Time=1.39 sec
#  ARIMA(1,1,2)(0,0,0)[12]             : AIC=2962.870, Time=0.08 sec
#  ARIMA(1,1,2)(0,0,2)[12]             : AIC=2597.699, Time=0.66 sec
#  ARIMA(1,1,2)(2,0,0)[12]             : AIC=2261.075, Time=0.59 sec
#  ARIMA(1,1,2)(2,0,2)[12]             : AIC=inf, Time=1.94 sec
#  ARIMA(0,1,2)(1,0,1)[12]             : AIC=2227.320, Time=0.35 sec
#  ARIMA(1,1,1)(1,0,1)[12]             : AIC=2211.827, Time=0.35 sec
#  ARIMA(2,1,2)(1,0,1)[12]             : AIC=2209.579, Time=0.91 sec
#  ARIMA(1,1,3)(1,0,1)[12]             : AIC=2210.247, Time=0.63 sec
#  ARIMA(0,1,1)(1,0,1)[12]             : AIC=2232.133, Time=0.26 sec
#  ARIMA(0,1,3)(1,0,1)[12]             : AIC=2226.229, Time=0.41 sec
#  ARIMA(2,1,1)(1,0,1)[12]             : AIC=2208.869, Time=0.49 sec
#  ARIMA(2,1,3)(1,0,1)[12]             : AIC=2211.656, Time=0.92 sec
#
# Best model:  ARIMA(1,1,2)(1,0,1)[12]
# Total fit time: 36.260 seconds
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                                       SARIMAX Results
# ============================================================================================
# Dep. Variable:                                    y   No. Observations:                  348
# Model:             SARIMAX(1, 1, 2)x(1, 0, [1], 12)   Log Likelihood               -1098.252
# Date:                              Mon, 07 Mar 2022   AIC                           2208.504
# Time:                                      20:25:41   BIC                           2231.600
# Sample:                                           0   HQIC                          2217.700
#                                               - 348
# Covariance Type:                                opg
# ==============================================================================
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# ar.L1          0.9247      0.045     20.582      0.000       0.837       1.013
# ma.L1         -0.9443      0.070    -13.467      0.000      -1.082      -0.807
# ma.L2          0.1287      0.060      2.131      0.033       0.010       0.247
# ar.S.L12       0.9972      0.001    703.303      0.000       0.994       1.000
# ma.S.L12      -0.7486      0.043    -17.284      0.000      -0.834      -0.664
# sigma2        29.3032      1.718     17.056      0.000      25.936      32.671
# ===================================================================================
# Ljung-Box (L1) (Q):                   0.00   Jarque-Bera (JB):                67.50
# Prob(Q):                              1.00   Prob(JB):                         0.00
# Heteroskedasticity (H):               0.85   Skew:                            -0.11
# Prob(H) (two-sided):                  0.40   Kurtosis:                         5.15
# ===================================================================================
#
# Warnings:
# [1] Covariance matrix calculated using the outer product of gradients (complex-step).
# """

# %%
# DON'T WRITE HERE
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                                  Statespace Model Results
# ==========================================================================================
# Dep. Variable:                                  y   No. Observations:                  348
# Model:             SARIMAX(0, 1, 0)x(2, 0, 0, 12)   Log Likelihood               -1134.664
# Date:                            Wed, 27 Mar 2019   AIC                           2277.328
# Time:                                    13:12:10   BIC                           2292.726
# Sample:                                         0   HQIC                          2283.459
#                                             - 348
# Covariance Type:                              opg
# ==============================================================================
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# intercept     -0.0477      0.292     -0.163      0.870      -0.620       0.524
# ar.S.L12       0.5291      0.040     13.286      0.000       0.451       0.607
# ar.S.L24       0.4303      0.041     10.453      0.000       0.350       0.511
# sigma2        37.2952      2.157     17.294      0.000      33.068      41.522
# ===================================================================================
# Ljung-Box (Q):                       99.53   Jarque-Bera (JB):                51.67
# Prob(Q):                              0.00   Prob(JB):                         0.00
# Heteroskedasticity (H):               0.86   Skew:                            -0.29
# Prob(H) (two-sided):                  0.42   Kurtosis:                         4.80
# ===================================================================================
#
# Warnings:
# [1] Covariance matrix calculated using the outer product of gradients (complex-step).
# """

# %% [markdown]
# You should see a recommended ARIMA Order of (0,1,0) combined with a seasonal order of (2,0,0,12).
# ### 4. Split the data into train/test sets
# Set one year (12 records) for testing. There is more than one way to do this!
#
# - `데이터를 훈련, 테스트 데이터 셋으로 분리`

# %%
train = df.iloc[:len(df)-12]
test = df.iloc[len(df)-12:]

# %%
# DON'T WRITE HERE

# %% [markdown]
# ### 5. Fit a SARIMA(0,1,0)(2,0,0,12) model to the training set
#
# `SARIMA 모델 피팅할 때 자동 ARIMA가 제공하는 차수 사용`

# %%
model = SARIMAX(train['Employees'], order=(0,1,0), seasonal_order=(2,0,0,12))
results = model.fit()
results.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                                      SARIMAX Results
# ==========================================================================================
# Dep. Variable:                          Employees   No. Observations:                  336
# Model:             SARIMAX(0, 1, 0)x(2, 0, 0, 12)   Log Likelihood               -1095.407
# Date:                            Mon, 07 Mar 2022   AIC                           2196.814
# Time:                                    20:26:21   BIC                           2208.256
# Sample:                                01-01-1990   HQIC                          2201.375
#                                      - 12-01-2017
# Covariance Type:                              opg
# ==============================================================================
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# ar.S.L12       0.5204      0.040     13.051      0.000       0.442       0.599
# ar.S.L24       0.4385      0.041     10.593      0.000       0.357       0.520
# sigma2        37.1907      2.165     17.175      0.000      32.947      41.435
# ===================================================================================
# Ljung-Box (L1) (Q):                   0.02   Jarque-Bera (JB):                56.66
# Prob(Q):                              0.89   Prob(JB):                         0.00
# Heteroskedasticity (H):               1.06   Skew:                            -0.35
# Prob(H) (two-sided):                  0.74   Kurtosis:                         4.89
# ===================================================================================
#
# Warnings:
# [1] Covariance matrix calculated using the outer product of gradients (complex-step).
# """

# %%
# DON'T WRITE HERE
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                                  Statespace Model Results
# ==========================================================================================
# Dep. Variable:                          Employees   No. Observations:                  336
# Model:             SARIMAX(0, 1, 0)x(2, 0, 0, 12)   Log Likelihood               -1095.407
# Date:                            Wed, 27 Mar 2019   AIC                           2196.814
# Time:                                    13:12:24   BIC                           2208.256
# Sample:                                01-01-1990   HQIC                          2201.375
#                                      - 12-01-2017
# Covariance Type:                              opg
# ==============================================================================
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# ar.S.L12       0.5204      0.040     13.051      0.000       0.442       0.599
# ar.S.L24       0.4385      0.041     10.593      0.000       0.357       0.520
# sigma2        37.1907      2.165     17.175      0.000      32.947      41.435
# ===================================================================================
# Ljung-Box (Q):                      102.80   Jarque-Bera (JB):                56.66
# Prob(Q):                              0.00   Prob(JB):                         0.00
# Heteroskedasticity (H):               1.06   Skew:                            -0.35
# Prob(H) (two-sided):                  0.74   Kurtosis:                         4.89
# ===================================================================================
#
# Warnings:
# [1] Covariance matrix calculated using the outer product of gradients (complex-step).
# """

# %% [markdown]
# ### 6. Obtain predicted values
#
# ` 예측된 값 얻기`

# %%
start = len(train)
end = len(train) + len(test) -1
predictions = results.predict(start, end, type='levels').rename('SARIMA Test Predictions')

# %%
# DON'T WRITE HERE

# %% [markdown]
# ### 7. Plot predictions against known values
# Optional: add a title and y-axis label.
#
# `알려진 값에 대한 예측을 플롯으로 그림`

# %%
test['Employees'].plot(figsize=(12,8), legend=True)
predictions.plot(legend=True);

# %%
# DON'T WRITE HERE

# %% [markdown]
# -  연초와 여름동안에는 꽤 잘하다가 늦가을 쯤에 과대 평가

# %% [markdown]
# ### 8. Evaluate the Model using MSE and RMSE
# You can run both from the same cell if you want.
#
# ` 평균 제곱 오차와 평균 제곱오차 제곱근 구함`

# %%
print(rmse(test['Employees'], predictions))
print(mean_squared_error(test['Employees'], predictions))
# Out:
# 13.522228539225294
# 182.85066466703904

# %%
# DON'T WRITE HERE
# Out:
# SARIMA(0,1,0)(2,0,0,12) MSE Error: 182.8506646
# SARIMA(0,1,0)(2,0,0,12) RMSE Error: 13.52222854

# %% [markdown]
# ### 9. Retrain the model on the full data and forecast one year into the future
#
# `전체 데이터에 대한 모델 재훈련, 1년 후에 미래 예측`

# %%
model = SARIMAX(df['Employees'], order=(0,1,0), seasonal_order=(2,0,0,12))
results= model.fit()
fcast = results.predict(start = len(df), end=len(df)+11, typ='levels').rename('SARIMA Forecast')

# %%
# DON'T WRITE HERE

# %% [markdown]
# ### 10. Plot the forecasted values alongside the original data
# Optional: add a title and y-axis label.
#
# `예측된 값 플롯으로 그리기, 계절성 추세와 일치하게 하기`

# %%
df['Employees'].plot(figsize=(12,8), legend=True)
fcast.plot();

# %%
# DON'T WRITE HERE

# %% [markdown]
# ## Great job!
